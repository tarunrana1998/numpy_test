# %%
import numpy as np
import pandas as pd

# %%
array = np.array([[1, 2, 3], [4, 5, 6]])
print(array * 2)
# Out:
# [[ 2  4  6]
#  [ 8 10 12]]

# %%
zeros = np.zeros((2, 3))
print(zeros)
# Out:
# [[0. 0. 0.]
#  [0. 0. 0.]]

# %%
stacked = np.array([[1, 2, 3],
                    [4, 5, 6]])
columns = np.array([[0],[0]])
with_rows = np.vstack((stacked,[[0,0,0],[0,0,0]]) )

print(with_rows)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [0 0 0]
#  [0 0 0]]

# %%
a = pd.Series([1, 2, 3, 4, 5], index=False)
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 a = pd.Series([1, 2, 3, 4, 5], index=False)
#       2 print(a)
#
# File ~/projects/personal/numpy_test/.venv/lib/python3.14/site-packages/pandas/core/series.py:423, in Series.__init__(self, data, index, dtype, name, copy)
#     420 name = ibase.maybe_extract_name(name, data, type(self))
#     422 if index is not None:
# --> 423     index = ensure_index(index)
#     425 if dtype is not None:
#     426     dtype = self._validate_dtype(dtype)
#
# File ~/projects/personal/numpy_test/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:7975, in ensure_index(index_like, copy)
#    7973         return Index(index_like, copy=copy, tupleize_cols=False)
#    7974 else:
# -> 7975     return Index(index_like, copy=copy)
#
# ...
